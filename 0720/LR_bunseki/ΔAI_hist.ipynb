# %%
# Lについて
import matplotlib.pyplot as plt
import pandas as pd

# 設定
q = 95
sp = "L"
f = "a"

# 入力ファイル
input_csv = f"/home/mitani/CSJ-emo-int_bunseki/0718/0720/LR_bunseki/data/vad_delta_{sp}.csv"

# CSV読み込み
df = pd.read_csv(input_csv)

# ヒストグラム
plt.hist(df["delta_arousal"], bins=50, edgecolor="black")
plt.title("Delta Arousal")
plt.xlabel("Δa")
plt.ylabel("Frequency")
plt.show()

plt.hist(df["delta_int_kushinada"], bins=50, edgecolor="black")
plt.title("Delta Intencity")
plt.xlabel("Δint")
plt.ylabel("Frequency")
plt.show()

# %%
# Rについて
